# %% [markdown]
# 并行素数筛算法, 基于埃氏筛, 使用DPC++

# %%
# %%writefile lab/parallel_Sieve.cpp
# #include <CL/sycl.hpp>
# #include <iostream>
# #include<ctime>
#
# using namespace sycl;
#
# int count(int *primes, const int end){
#     int cnt = 0;
#     for (int i = 2; i < end; i++) {
#         if (primes[i]){
#             cnt++;
#             //std::cout << i << " ";
#         }
#     }
#     return cnt;
# }
#
# int parallel_sieve(queue &q, int *primes, const int N, const int blocks){
#     clock_t start, end;
#     for (int i = 2; i < N; i++) {
#         primes[i] = 1;
#     }
#     int curr_prime = 2;
#     start = clock();
#     while (primes[curr_prime]){
#         int bounds = N / curr_prime + 1;
#         int piece = (bounds/blocks + 1)*curr_prime;
#         q.parallel_for(range<1>(blocks), [=](id<1> i) {
#             int start = curr_prime + i*piece;
#             int end = i<(blocks-1)?(start+piece):N;
#             // int end = start + piece;
#             // end = end > N ? N : end;
#             //if(i == blocks - 1){
#             //   end = N;
#             //}else{
#             //   end = start + piece;
#             //}
#             for (int j = start; j < end; j += curr_prime) {
#                 primes[j] = 0;
#             }
#         }).wait();
#         primes[curr_prime ++] = 1;
#         while (curr_prime <= sqrt(N) && !primes[curr_prime]) {
#             curr_prime ++;
#         }
#     }
#     end = clock();
#     return end-start;
# }
#
# int serial_sieve(int *primes, const int N){
#     clock_t start, end;
#     for (int i = 2; i < N; i++) {
#         primes[i] = 1;
#     }
#     start = clock();
#     for (int i = 2; i < sqrt(N); ++i) {
#         if (primes[i]) {
#             for (int j = 2 * i; j < N; j += i) {
#                 primes[j] = 0;
#             }
#         }
#     }
#     end = clock();
#     return end-start;
# }
#
# void test(queue q, const int N, const int blocks){
#     //queue q;
#     int *primes = malloc_shared<int>(N, q);
#     std::cout<<"-------------------------------------\n";
#     std::cout<<"Num of Numbers: "<<N<<"\tNum of blocks:"<<blocks<<std::endl;
#     std::cout<< "parallel used time: "<< parallel_sieve(q, primes, N, blocks) <<std::flush;;
#     //std::cout<<"\ttotal: "<< count(primes, N);
#     std::cout<< "\nserial used time: "<< serial_sieve(primes, N) <<std::flush;
#     //std::cout<<"\t total: "<< count(primes, N);
#     std::cout<<"\n-------------------------------------"<<std::endl;;
#     free(primes, q);
# }
# int main() {
#     queue q(gpu_selector_v);
#     int Ns[] = {1024, 1024*1024, 1024*1024*32, 1024*1024*128, 1024*1024*512, 1024*1024*1024};
#     int Nblocks[] = {8, 16, 32, 64, 128, 256, 512};
#     // 由于的devcloud只允许程序运行一分钟时间, 所以网格要手动调整多次
#     for(int i=0; i<2; i++){
#         for(int j=0; j<7; j++){
#             test(q, Ns[i], Nblocks[j]);
#         }
#     }
#     return 0;
# }
# Out:
# Overwriting lab/parallel_Sieve.cpp

# %% [markdown]
# 运行程序

# %%
! chmod 755 q; chmod 755 run_Sieve.sh;if [ -x "$(command -v qsub)" ]; then ./q run_Sieve.sh; else ./run_Sieve.sh; fi
# Out:
# Job has been submitted to Intel(R) DevCloud and will execute soon.
#
# Job ID                    Name             User            Time Use S Queue
# ------------------------- ---------------- --------------- -------- - -----
# 2184491.v-qsvr-1           ...ub-singleuser u174863         00:00:08 R jupyterhub
# 2184508.v-qsvr-1           run_Sieve.sh     u174863                0 Q batch
#
# Waiting for Output ██████████████████ Done⬇
#
# ########################################################################
# #      Date:           Thu 09 Feb 2023 09:07:50 PM PST
# #    Job ID:           2184508.v-qsvr-1.aidevcloud
# #      User:           u174863
# # Resources:           cput=75:00:00,neednodes=1:gpu:ppn=2,nodes=1:gpu:ppn=2,walltime=06:00:00
# ########################################################################
#
# ## u174863 is compiling parallel_Sieve algorithm parallel_Sieve.cpp
# -------------------------------------
# Num of Numbers: 33554432	Num of blocks:8
# parallel used time: 473598
# serial used time: 393289
# -------------------------------------
# -------------------------------------
# Num of Numbers: 33554432	Num of blocks:16
# parallel used time: 364178
# serial used time: 391461
# -------------------------------------
# -------------------------------------
# Num of Numbers: 33554432	Num of blocks:32
# parallel used time: 352465
# serial used time: 392306
# -------------------------------------
# -------------------------------------
# Num of Numbers: 33554432	Num of blocks:64
# parallel used time: 364010
# serial used time: 391844
# -------------------------------------
# -------------------------------------
# Num of Numbers: 33554432	Num of blocks:128
# parallel used time: 377802
# serial used time: 392693
# -------------------------------------
# -------------------------------------
# Num of Numbers: 33554432	Num of blocks:256
# parallel used time: 381944
# serial used time: 392644
# -------------------------------------
# -------------------------------------
# Num of Numbers: 33554432	Num of blocks:512
# parallel used time: 381289
# serial used time: 393465
# -------------------------------------
#
# ########################################################################
# # End of output for job 2184508.v-qsvr-1.aidevcloud
# # Date: Thu 09 Feb 2023 09:08:04 PM PST
# ########################################################################
#
# Job Completed in 18 seconds.

# %%
! chmod 755 q; chmod 755 run_Sieve.sh; ./q run_Sieve.sh nodes=2:gpu:ppn=2; fi
# Out:
# Job has been submitted to Intel(R) DevCloud and will execute soon.
#
# Job ID                    Name             User            Time Use S Queue
# ------------------------- ---------------- --------------- -------- - -----
# 2184491.v-qsvr-1           ...ub-singleuser u174863         00:00:06 R jupyterhub
# 2184505.v-qsvr-1           run_Sieve.sh     u174863                0 Q batch
#
# Waiting for Output █████████████████████ Done⬇
#
# ########################################################################
# #      Date:           Thu 09 Feb 2023 09:02:38 PM PST
# #    Job ID:           2184505.v-qsvr-1.aidevcloud
# #      User:           u174863
# # Resources:           cput=75:00:00,neednodes=1:gpu:ppn=2,nodes=1:gpu:ppn=2,walltime=06:00:00
# ########################################################################
#
# ## u174863 is compiling parallel_Sieve algorithm parallel_Sieve.cpp
# -------------------------------------
# Num of Numbers: 1024	Num of blocks:8
# parallel used time: 51204
# serial used time: 1
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1024	Num of blocks:16
# parallel used time: 434
# serial used time: 1
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1024	Num of blocks:32
# parallel used time: 343
# serial used time: 1
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1024	Num of blocks:64
# parallel used time: 335
# serial used time: 1
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1024	Num of blocks:128
# parallel used time: 351
# serial used time: 1
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1024	Num of blocks:256
# parallel used time: 396
# serial used time: 1
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1024	Num of blocks:512
# parallel used time: 359
# serial used time: 1
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1048576	Num of blocks:8
# parallel used time: 14267
# serial used time: 2115
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1048576	Num of blocks:16
# parallel used time: 10570
# serial used time: 2104
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1048576	Num of blocks:32
# parallel used time: 8234
# serial used time: 2090
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1048576	Num of blocks:64
# parallel used time: 7572
# serial used time: 2094
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1048576	Num of blocks:128
# parallel used time: 7702
# serial used time: 2097
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1048576	Num of blocks:256
# parallel used time: 7706
# serial used time: 2089
# -------------------------------------
# -------------------------------------
# Num of Numbers: 1048576	Num of blocks:512
# parallel used time: 7843
# serial used time: 2092
# -------------------------------------
#
# ########################################################################
# # End of output for job 2184505.v-qsvr-1.aidevcloud
# # Date: Thu 09 Feb 2023 09:02:47 PM PST
# ########################################################################
#
# Job Completed in 21 seconds.
